# %% [markdown]
# <a href="https://colab.research.google.com/github/Ananth-08/breast_cancer_4cnn/blob/main/modelstrained.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# !git clone https://github.com/Ananth-08/breast_cancer_4cnn.git
# %cd breast_cancer_4cnn
# Out:
# Cloning into 'breast_cancer_4cnn'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 12 (delta 2), reused 12 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (12/12), done.
# Resolving deltas: 100% (2/2), done.
# /content/breast_cancer_4cnn

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/data.zip -d ./data
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: ./data/data/200X/train/malignant/SOB_M_DC-14-13412-200-006.png
#   inflating: ./data/data/200X/train/malignant/SOB_M_DC-14-13412-200-007.png
#   inflating: ./data/data/200X/train/malignant/SOB_M_DC-14-13412-200-008.png
#   inflating: ./data/data/200X/train/malignant/SOB_M_DC-14-13412-200-009.png
#   inflating: ./data/data/200X/train/malignant/SOB_M_DC-14-13412-200-010.png
#   inflating: ./data/data/200X/train/malignant/SOB_M_DC-14-13412-200-012.png
#   inflating: ./data/data/200X/train/malignant/SOB_M_DC-14-13412-200-013.png
#   inflating: ./data/data/200X/train/malignant/SOB_M_DC-14-13412-200-014.png
#   inflating: ./data/data/200X/train/malignant/SOB_M_DC-14-13412-200-015.png
#   inflating: ./data/data/200X/train/malignant/SOB_M_DC-14-13412-200-016.png
#   inflating: ./data/data/200X/train/malignant/SOB_M_DC-14-13412-200-017.png
#   inflating: ./data/data/200X/train/malignant/SOB_M_DC-14-13412-200-018.png
# ...

# %%
# !python src/train_200x.py
# Out:
# Using device: cpu
# Using threshold: 0.6
# Classes: ['benign', 'malignant']
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 146MB/s]
# Epoch [1/14] Loss: 0.3229 Val Acc: 84.42% Recall(M): 86.15%
# ...

# %%
# !git pull
# Out:
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 4 (delta 2), reused 4 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 1.08 KiB | 1.08 MiB/s, done.
# From https://github.com/Ananth-08/breast_cancer_4cnn
#    db9728b..7f25568  main       -> origin/main
# Updating db9728b..7f25568
# Fast-forward
#  src/test_200x.py | 64 ++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#  1 file changed, 64 insertions(+)
#  create mode 100644 src/test_200x.py

# %%
# !python src/test_200x.py
# Out:
# Using device: cuda
# Classes: ['benign', 'malignant']
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# TEST Accuracy: 87.00%
# TEST Recall (Malignant): 98.30%
# Confusion Matrix:
# [[ 30  35]
#  [  4 231]]

# %%
# !git pull
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 460 bytes | 460.00 KiB/s, done.
# From https://github.com/Ananth-08/breast_cancer_4cnn
#    7f25568..9e8a9f3  main       -> origin/main
# Updating 7f25568..9e8a9f3
# Fast-forward
#  src/train_200x.py | 8 ++++++--
#  1 file changed, 6 insertions(+), 2 deletions(-)

# %%
# !python src/train_200x.py
# Out:
# Using device: cuda
# Using threshold: 0.6
# Classes: ['benign', 'malignant']
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch [1/14] Loss: 0.2986 Val Acc: 85.80% Recall(M): 95.69%
# Epoch [2/14] Loss: 0.1956 Val Acc: 84.29% Recall(M): 97.61%
# Epoch [3/14] Loss: 0.1557 Val Acc: 83.38% Recall(M): 99.04%
# Epoch [4/14] Loss: 0.1312 Val Acc: 80.97% Recall(M): 99.52%
# ...

# %%
# !python src/test_200x.py
# Out:
# Using device: cuda
# Classes: ['benign', 'malignant']
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# TEST Accuracy: 87.33%
# TEST Recall (Malignant): 100.00%
# Confusion Matrix:
# [[ 27  38]
#  [  0 235]]

# %%
from google.colab import drive
drive.mount('/content/drive')
# !ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# drive  sample_data

# %%
# !mv data/data/* data/
# !rmdir data/data

# %%
# !python src/train_400x.py
# Out:
# Using device: cuda
# Using threshold: 0.6
# Classes: ['benign', 'malignant']
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch [1/14] Loss: 0.3284 Val Acc: 76.64% Recall(M): 100.00%
# Epoch [2/14] Loss: 0.2580 Val Acc: 80.92% Recall(M): 87.70%
# Epoch [3/14] Loss: 0.1976 Val Acc: 81.91% Recall(M): 91.98%
# Epoch [4/14] Loss: 0.1264 Val Acc: 72.04% Recall(M): 82.89%
# ...

# %%
# !git commit -m "after train of 40x 2.0"
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@f1f874f3acfd.(none)')

# %%
# !git config --global user.email "ananthak1506@gmail.com"
# !git config --global user.name "Ananth-08"

# %%
# !git push origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !cd /content/drive/MyDrive/data/data/40X/train

# %%
# !cd /content/drive/MyDrive/data

# %%
# !cd /content/breast_cancer_4cnn

# %%
# !unzip /content/drive/MyDrive/data.zip -d ./data
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: ./data/data/200X/train/malignant/SOB_M_DC-14-13412-200-006.png
#   inflating: ./data/data/200X/train/malignant/SOB_M_DC-14-13412-200-007.png
#   inflating: ./data/data/200X/train/malignant/SOB_M_DC-14-13412-200-008.png
#   inflating: ./data/data/200X/train/malignant/SOB_M_DC-14-13412-200-009.png
#   inflating: ./data/data/200X/train/malignant/SOB_M_DC-14-13412-200-010.png
#   inflating: ./data/data/200X/train/malignant/SOB_M_DC-14-13412-200-012.png
#   inflating: ./data/data/200X/train/malignant/SOB_M_DC-14-13412-200-013.png
#   inflating: ./data/data/200X/train/malignant/SOB_M_DC-14-13412-200-014.png
#   inflating: ./data/data/200X/train/malignant/SOB_M_DC-14-13412-200-015.png
#   inflating: ./data/data/200X/train/malignant/SOB_M_DC-14-13412-200-016.png
#   inflating: ./data/data/200X/train/malignant/SOB_M_DC-14-13412-200-017.png
#   inflating: ./data/data/200X/train/malignant/SOB_M_DC-14-13412-200-018.png
# ...

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# !unzip /content/drive/MyDrive/data.zip -d ./data
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: ./data/data/200X/train/malignant/SOB_M_DC-14-13412-200-006.png
#   inflating: ./data/data/200X/train/malignant/SOB_M_DC-14-13412-200-007.png
#   inflating: ./data/data/200X/train/malignant/SOB_M_DC-14-13412-200-008.png
#   inflating: ./data/data/200X/train/malignant/SOB_M_DC-14-13412-200-009.png
#   inflating: ./data/data/200X/train/malignant/SOB_M_DC-14-13412-200-010.png
#   inflating: ./data/data/200X/train/malignant/SOB_M_DC-14-13412-200-012.png
#   inflating: ./data/data/200X/train/malignant/SOB_M_DC-14-13412-200-013.png
#   inflating: ./data/data/200X/train/malignant/SOB_M_DC-14-13412-200-014.png
#   inflating: ./data/data/200X/train/malignant/SOB_M_DC-14-13412-200-015.png
#   inflating: ./data/data/200X/train/malignant/SOB_M_DC-14-13412-200-016.png
#   inflating: ./data/data/200X/train/malignant/SOB_M_DC-14-13412-200-017.png
#   inflating: ./data/data/200X/train/malignant/SOB_M_DC-14-13412-200-018.png
# ...

# %%
# !git clone https://github.com/Ananth-08/breast_cancer_4cnn.git
# %cd breast_cancer_4cnn
# Out:
# Cloning into 'breast_cancer_4cnn'...
# remote: Enumerating objects: 32, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 32 (delta 16), reused 23 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (32/32), 5.34 KiB | 5.34 MiB/s, done.
# Resolving deltas: 100% (16/16), done.
# /content/breast_cancer_4cnn/breast_cancer_4cnn

# %%
# !cd ..

# %%
# !git clone https://github.com/Ananth-08/breast_cancer_4cnn.git
# %cd breast_cancer_4cnn
# Out:
# Cloning into 'breast_cancer_4cnn'...
# remote: Enumerating objects: 55, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 55 (delta 28), reused 37 (delta 10), pack-reused 0 (from 0)
# Receiving objects: 100% (55/55), 1.97 MiB | 6.24 MiB/s, done.
# Resolving deltas: 100% (28/28), done.
# /content/breast_cancer_4cnn

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python src/train_40x.py
# Out:
# Using device: cuda
# Using threshold: 0.6
# Traceback (most recent call last):
#   File "/content/breast_cancer_4cnn/src/train_40x.py", line 42, in <module>
#     train_ds = datasets.ImageFolder(os.path.join(DATA_DIR, "train"), transform=train_tf)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torchvision/datasets/folder.py", line 328, in __init__
#     super().__init__(
#   File "/usr/local/lib/python3.12/dist-packages/torchvision/datasets/folder.py", line 149, in __init__
#     classes, class_to_idx = self.find_classes(self.root)
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torchvision/datasets/folder.py", line 234, in find_classes
#     return find_classes(directory)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torchvision/datasets/folder.py", line 41, in find_classes
# ...

# %%
# !python src/fusion_predict.py
# Out:
# Patient: patient01
# {'prediction': 'MALIGNANT', 'confidence_percent': 99.89, 'individual_model_probs': {'40X': 1.0, '100X': 1.0, '200X': 0.997, '400X': 0.999}}
